# %%
# !python2 preprocess.py test-processed.csv
# Out:
# Traceback (most recent call last):
#   File "preprocess.py", line 107, in <module>
#     preprocess_csv(csv_file_name, processed_file_name, test_file=False)
#   File "preprocess.py", line 81, in preprocess_csv
#     positive = int(line[:line.find(',')])
# ValueError: invalid literal for int() with base 10: 'is so sad for my apl friend'

# %%
# !python2 preprocess.py train-processed.csv
# Out:
# Processing 100000/100000
# Saved processed tweets to: train-processed-processed.csv

# %%
# !python2 stats.py train-processed-processed.csv
# Out:
# Processing 100000/100000
# Calculating frequency distribution
# Saved uni-frequency distribution to train-processed-processed-freqdist.pkl
# Saved bi-frequency distribution to train-processed-processed-freqdist-bi.pkl
#
# [Analysis Statistics]
# Tweets => Total: 100000, Positive: 56462, Negative: 43538
# User Mentions => Total: 0, Avg: 0.0000, Max: 0
# URLs => Total: 0, Avg: 0.0000, Max: 0
# Emojis => Total: 0, Positive: 0, Negative: 0, Avg: 0.0000, Max: 0
# Words => Total: 1283269, Unique: 50361, Avg: 12.8327, Max: 41, Min: 0
# Bigrams => Total: 1183437, Unique: 392543, Avg: 11.8344

# %%
# !python2 stats.py test-processed-processed.csv
# Out:
# Calculating frequency distribution
# Saved uni-frequency distribution to test-processed-processed-freqdist.pkl
# Saved bi-frequency distribution to test-processed-processed-freqdist-bi.pkl
#
# [Analysis Statistics]
# Tweets => Total: 0, Positive: 0, Negative: 0
# Traceback (most recent call last):
#   File "stats.py", line 106, in <module>
#     print 'User Mentions => Total: %d, Avg: %.4f, Max: %d' % (num_mentions, num_mentions / float(num_tweets), max_mentions)
# ZeroDivisionError: float division by zero

# %%
# !python2 baseline.py TRAIN = True
# Out:
# Correct = 65.32%

# %%
# !python2 naivebayes.py TRAIN = True
# Out:
# Generating feature vectors
# Processing 100000/100000
#
# Extracting features & training batches
# Processing 1/1
#
# Testing
# Processing 1/1
# Correct: 7773/10000 = 77.7300 %

# %%
# !python3 logistic.py TRAIN = True
# Out:
# Generating feature vectors
# Processing 100000/100000
#
# Extracting features & training batches
# 2022-01-21 07:19:42.615278: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Iteration 3/180, loss:0.6920, acc:0.51602022-01-21 07:19:43.712362: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 4/180, loss:0.6898, acc:0.56202022-01-21 07:19:43.804509: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 5/180, loss:0.6890, acc:0.58802022-01-21 07:19:43.901256: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 11/180, loss:0.6846, acc:0.60602022-01-21 07:19:44.491091: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# ...

# %%
# !python2 randomforest.py TRAIN = True
# Out:
# Generating feature vectors
# Processing 100000/100000
#
# Extracting features & training batches
# Processing 1/1/usr/local/lib/python2.7/dist-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
#
#
# Testing
# Processing 1/1
# Correct: 7253/10000 = 72.5300 %

# %%
# !python2 decisiontree.py TRAIN = True
# Out:
# Generating feature vectors
# Processing 100000/100000
#
# Extracting features & training batches
# Processing 1/1
#
# Testing
# Processing 1/1
# Correct: 6800/10000 = 68.0000 %

# %%
# !python2 svm.py TRAIN = True
# Out:
# Generating feature vectors
# Processing 100000/100000
#
# Extracting features & training batches
# Processing 1/1
#
# Testing
# Processing 1/1
# Correct: 7840/10000 = 78.4000 %

# %%
# !python3 neuralnet.py TRAIN = True
# Out:
# Generating feature vectors
# Processing 100000/100000
#
# Extracting features & training batches
# 2022-01-21 08:17:38.132441: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Iteration 180/180, loss:0.5234, acc:0.7480
# Epoch: 1, val_acc:0.7566
# Accuracy improved from 0.0000 to 0.7566, saving model
# Iteration 180/180, loss:0.4769, acc:0.7720
# Epoch: 2, val_acc:0.7596
# Accuracy improved from 0.7566 to 0.7596, saving model
# Iteration 180/180, loss:0.4476, acc:0.7920
# Epoch: 3, val_acc:0.7677
# Accuracy improved from 0.7596 to 0.7677, saving model
# Iteration 180/180, loss:0.4300, acc:0.7820
# Epoch: 4, val_acc:0.7645
# Iteration 180/180, loss:0.4147, acc:0.8080
# Epoch: 5, val_acc:0.7652
# Testing
# Generating feature vectors
#
#
# Predicting batches
#
# Saved to 1layerneuralnet.csv

# %%
pip install xgboost

# %%
#mendownload data glove untuk menjalankan cnn dan lstm
# !wget http://nlp.stanford.edu/data/glove.6B.zip /content/drive/MyDrive/FINAL EXAM/
# Out:
# --2022-01-22 07:38:29--  http://nlp.stanford.edu/data/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/glove.6B.zip [following]
# --2022-01-22 07:38:29--  https://nlp.stanford.edu/data/glove.6B.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip [following]
# --2022-01-22 07:38:29--  http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182613 (822M) [application/zip]
# ...

# %%
#mengekstrak data glove
# !unzip /content/dataset/glove*.zip
# Out:
# Archive:  /content/dataset/glove.6B.zip
#   inflating: glove.6B.50d.txt
#   inflating: glove.6B.100d.txt
#   inflating: glove.6B.200d.txt
#   inflating: glove.6B.300d.txt

# %%
# !python3 models/cnn.py
# Out:
# Looking for GLOVE seeds
# Processing 400000/0
#
# Generating feature vectors
# Processing 100000/100000
#
# 2022-01-21 10:05:40.506230: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Epoch 1/3
# 704/704 [==============================] - 653s 926ms/step - loss: 0.5331 - accuracy: 0.7233 - val_loss: 0.4753 - val_accuracy: 0.7685
# Epoch 2/3
# 704/704 [==============================] - 651s 925ms/step - loss: 0.4487 - accuracy: 0.7894 - val_loss: 0.4585 - val_accuracy: 0.7799
# Epoch 3/3
# 704/704 [==============================] - 652s 925ms/step - loss: 0.3971 - accuracy: 0.8200 - val_loss: 0.4724 - val_accuracy: 0.7783

# %%
#Semakin banyak proses epoch atau training dilakukan makan semakin meningkat akurasinya
# !python3 models/lstm.py
# Out:
# Looking for GLOVE vectors
# Processing 400000/0
#
# Found 31735 words in GLOVE
# Generating feature vectors
# Processing 100000/100000
#
# 2022-01-22 09:59:39.774172: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 40, 100)           9000100
#
#  dropout (Dropout)           (None, 40, 100)           0
#
#  lstm (LSTM)                 (None, 128)               117248
#
#  dense (Dense)               (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  activation (Activation)     (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
#  activation_1 (Activation)   (None, 1)                 0
#
# ...
# Total params: 9,125,669
# ...
